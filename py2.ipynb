# %%
#2.1
import pandas as pd
import datetime
import matplotlib.pyplot as plt
a=pd.read_csv('2281305.csv')
a['WS']=a['WND'].str.split(',').str.get(3)
b=a.drop(a[a['WS']=='9999'].index)
#f=a['DATE']
#g=pd.Series.tolist(f)
idx = pd.date_range("2010-01-02", periods=111346, freq="H")
d=b['WS'].astype(int)
e=pd.Series.tolist(d)
ts = pd.Series(e, index=idx)
ts.resample("1M").mean().plot()
# Out:
# <AxesSubplot:>

# %%
b['WS'].max()
# Out:
# '0190'

# %%
ts.max()
# Out:
# 9999
